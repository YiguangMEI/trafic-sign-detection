# %%
# %reload_ext autoreload
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
from src.model import model
import pandas as pd
import os
import joblib
#load model
seed = 42
my_model = model(seed)
my_model.classifier = joblib.load("src/models/hog_prob.pkl")
print(my_model.classifier)
# Out:
# SVC(C=10, class_weight='balanced', kernel='linear', max_iter=10000,
#     probability=True, random_state=42, verbose=0)

# %%
from detection import detection_images_in_folder

image_path = "dataset/val/images"

## detect the images in val  it will sortir an detections.csv
detection_images_in_folder(image_path, my_model, 'detections.csv')
# Out:
# Detecting traffic signs:   0%|          | 0/87 [00:00<?, ?it/s]
# 0297.jpg
# imagesize: 750 1000
# windowsize: 675 675
# step_size: 135
# windowsize: 600 600
# step_size: 120
# windowsize: 525 525
# step_size: 105
# windowsize: 450 450
# step_size: 90
# windowsize: 375 375
# step_size: 75
# windowsize: 300 300
# step_size: 60
# windowsize: 225 225
# step_size: 45
# windowsize: 150 150
# step_size: 30
# imagesize: 750 1000
# windowsize: 409 900
# step_size: 180 81
# windowsize: 363 800
# step_size: 160 72
# windowsize: 318 700
# step_size: 140 63
# windowsize: 272 600
# step_size: 120 54
# windowsize: 227 500
# step_size: 100 45
# windowsize: 181 400
# step_size: 80 36
# windowsize: 136 300
# step_size: 60 27
# windowsize: 90 200
# step_size: 40 18
# Detecting traffic signs:   1%|          | 1/87 [00:27<39:45, 27.74s/it]
# [(300, 320, 390, 520, 'fvert', 0.9172796257386443), (520, 400, 610, 600, 'fvert', 0.9194947608648661)]
# 0810.jpg
# imagesize: 750 1000
# windowsize: 675 675
# step_size: 135
# windowsize: 600 600
# step_size: 120
# windowsize: 525 525
# step_size: 105
# windowsize: 450 450
# step_size: 90
# windowsize: 375 375
# step_size: 75
# windowsize: 300 300
# step_size: 60
# windowsize: 225 225
# step_size: 45
# windowsize: 150 150
# step_size: 30
# imagesize: 750 1000
# windowsize: 409 900
# step_size: 180 81
# windowsize: 363 800
# step_size: 160 72
# windowsize: 318 700
# step_size: 140 63
# windowsize: 272 600
# step_size: 120 54
# windowsize: 227 500
# step_size: 100 45
# windowsize: 181 400
# step_size: 80 36
# windowsize: 136 300
# step_size: 60 27
# windowsize: 90 200
# step_size: 40 18
# Detecting traffic signs:   2%|▏         | 2/87 [00:55<39:32, 27.92s/it]
# [(340, 520, 430, 720, 'fvert', 0.9212079487709047), (280, 680, 370, 880, 'fvert', 0.9772999953442412), (300, 680, 390, 880, 'fvert', 0.9740263424084554), (320, 680, 410, 880, 'fvert', 0.972616159427989), (340, 680, 430, 880, 'fvert', 0.9666241493242117)]
# 0419.jpg
# imagesize: 750 1000
# windowsize: 675 675
# step_size: 135
# windowsize: 600 600
# step_size: 120
# windowsize: 525 525
# step_size: 105
# windowsize: 450 450
# step_size: 90
# windowsize: 375 375
# step_size: 75
# windowsize: 300 300
# step_size: 60
# windowsize: 225 225
# step_size: 45
# windowsize: 150 150
# step_size: 30
# imagesize: 750 1000
# windowsize: 409 900
# step_size: 180 81
# windowsize: 363 800
# step_size: 160 72
# windowsize: 318 700
# step_size: 140 63
# windowsize: 272 600
# step_size: 120 54
# windowsize: 227 500
# step_size: 100 45
# windowsize: 181 400
# step_size: 80 36
# windowsize: 136 300
# step_size: 60 27
# windowsize: 90 200
# step_size: 40 18
# Detecting traffic signs:   3%|▎         | 3/87 [01:24<39:32, 28.24s/it]
# [(300, 300, 527, 800, 'frouge', 0.9103566485472713), (480, 0, 661, 400, 'fvert', 0.9085436880056066), (480, 80, 661, 480, 'fvert', 0.9629353190633673), (320, 320, 501, 720, 'frouge', 0.9245457918515277), (180, 0, 316, 300, 'forange', 0.9249965221900817), (270, 0, 406, 300, 'forange', 0.9019333523504617), (480, 0, 616, 300, 'fvert', 0.9633077912945374), (480, 60, 616, 360, 'fvert', 0.9724767014891339), (480, 120, 616, 420, 'fvert', 0.9133098004223974), (480, 180, 616, 480, 'fvert', 0.9111010720115275), (480, 240, 616, 540, 'fvert', 0.908962197310585), (360, 360, 496, 660, 'frouge', 0.9580471753704278), (0, 0, 90, 200, 'forange', 0.9231160044272056), (200, 0, 290, 200, 'forange', 0.9416203129519629), (220, 0, 310, 200, 'forange', 0.96028704365306), (400, 0, 490, 200, 'fvert', 0.9645921574063331), (420, 0, 510, 200, 'fvert', 0.9836610330519826), (440, 0, 530, 200, 'fvert', 0.9352698969698549), (480, 0, 570, 200, 'fvert', 0.9235007875911484), (200, 40, 290, 240, 'forange', 0.9709444285473677), (380, 40, 470, 240, 'forange', 0.9495777874813158), (480, 80, 570, 280, 'fvert', 0.9041911250753492), (480, 240, 570, 440, 'fvert', 0.9609610236707011), (100, 280, 190, 480, 'fvert', 0.9763644024826471), (200, 320, 290, 520, 'frouge', 0.9323649768339679), (200, 360, 290, 560, 'frouge', 0.9306218801428922), (440, 440, 530, 640, 'fvert', 0.9323773388850414)]
# 0733.jpg
# imagesize: 750 1000
# windowsize: 675 675
# step_size: 135
# windowsize: 600 600
# step_size: 120
# windowsize: 525 525
# step_size: 105
# windowsize: 450 450
# step_size: 90
# windowsize: 375 375
# step_size: 75
# windowsize: 300 300
# step_size: 60
# windowsize: 225 225
# step_size: 45
# windowsize: 150 150
# step_size: 30
# imagesize: 750 1000
# windowsize: 409 900
# step_size: 180 81
# windowsize: 363 800
# step_size: 160 72
# windowsize: 318 700
# step_size: 140 63
# windowsize: 272 600
# step_size: 120 54
# windowsize: 227 500
# step_size: 100 45
# windowsize: 181 400
# step_size: 80 36
# windowsize: 136 300
# step_size: 60 27
# windowsize: 90 200
# step_size: 40 18
# Detecting traffic signs:   5%|▍         | 4/87 [01:53<39:26, 28.51s/it]
# [(0, 160, 363, 960, 'forange', 0.9034880049132671), (420, 140, 738, 840, 'forange', 0.9198921517102141), (420, 0, 692, 600, 'frouge', 0.9041399147728387), (420, 240, 692, 840, 'forange', 0.9437030431542155), (500, 200, 727, 700, 'fvert', 0.9590199365302676), (450, 300, 677, 800, 'forange', 0.9531085333981955), (560, 80, 741, 480, 'fvert', 0.9003929255881818), (560, 160, 741, 560, 'fvert', 0.9245594192932319), (480, 240, 661, 640, 'fvert', 0.9613404759938164), (520, 240, 701, 640, 'fvert', 0.9221454629436711), (560, 240, 741, 640, 'fvert', 0.955423730842257), (440, 320, 621, 720, 'forange', 0.9416846137065696), (570, 240, 706, 540, 'fvert', 0.9255411640531496), (600, 240, 736, 540, 'fvert', 0.9704493357418088), (510, 300, 646, 600, 'fvert', 0.968112533209097), (570, 300, 706, 600, 'fvert', 0.907783144957654), (450, 360, 586, 660, 'forange', 0.9577297209775069), (120, 0, 210, 200, 'fvert', 0.9080549896538475), (240, 0, 330, 200, 'fvert', 0.9561117053703173), (260, 0, 350, 200, 'fvert', 0.9495192004573383), (280, 0, 370, 200, 'fvert', 0.932615931426953), (300, 0, 390, 200, 'fvert', 0.9370273337200951), (480, 320, 570, 520, 'fvert', 0.9104273205591078), (500, 440, 590, 640, 'forange', 0.95633805233858), (520, 440, 610, 640, 'forange', 0.9603805718828561), (580, 440, 670, 640, 'forange', 0.9174082011257665), (460, 480, 550, 680, 'frouge', 0.9144910243452736), (520, 480, 610, 680, 'frouge', 0.9409269477967301), (460, 520, 550, 720, 'frouge', 0.9413884385536001)]
# 0385.jpg
# imagesize: 1000 1000
# windowsize: 900 900
# step_size: 180
# windowsize: 800 800
# step_size: 160
# windowsize: 700 700
# step_size: 140
# windowsize: 600 600
# step_size: 120
# windowsize: 500 500
# step_size: 100
# windowsize: 400 400
# step_size: 80
# windowsize: 300 300
# step_size: 60
# windowsize: 200 200
# step_size: 40
# imagesize: 1000 1000
# windowsize: 409 900
# step_size: 180 81
# windowsize: 363 800
# step_size: 160 72
# windowsize: 318 700
# step_size: 140 63
# windowsize: 272 600
# step_size: 120 54
# windowsize: 227 500
# step_size: 100 45
# windowsize: 181 400
# step_size: 80 36
# windowsize: 136 300
# step_size: 60 27
# windowsize: 90 200
# step_size: 40 18
# Detecting traffic signs:   6%|▌         | 5/87 [02:23<39:32, 28.93s/it]
# []
# 0248.jpg
# imagesize: 715 1000
# windowsize: 643 643
# step_size: 128
# windowsize: 572 572
# step_size: 114
# windowsize: 500 500
# step_size: 100
# windowsize: 429 429
# step_size: 85
# windowsize: 357 357
# step_size: 71
# windowsize: 286 286
# step_size: 57
# windowsize: 214 214
# step_size: 42
# imagesize: 715 1000
# windowsize: 409 900
# step_size: 180 81
# windowsize: 363 800
# step_size: 160 72
# windowsize: 318 700
# step_size: 140 63
# windowsize: 272 600
# step_size: 120 54
# windowsize: 227 500
# step_size: 100 45
# windowsize: 181 400
# step_size: 80 36
# windowsize: 136 300
# step_size: 60 27
# windowsize: 90 200
# step_size: 40 18
# Detecting traffic signs:   7%|▋         | 6/87 [02:43<35:08, 26.03s/it]
# []
# 0878.jpg
# imagesize: 715 1000
# windowsize: 643 643
# step_size: 128
# windowsize: 572 572
# step_size: 114
# windowsize: 500 500
# step_size: 100
# windowsize: 429 429
# step_size: 85
# windowsize: 357 357
# step_size: 71
# windowsize: 286 286
# step_size: 57
# windowsize: 214 214
# step_size: 42
# imagesize: 715 1000
# windowsize: 409 900
# step_size: 180 81
# windowsize: 363 800
# step_size: 160 72
# windowsize: 318 700
# step_size: 140 63
# windowsize: 272 600
# step_size: 120 54
# windowsize: 227 500
# step_size: 100 45
# windowsize: 181 400
# step_size: 80 36
# windowsize: 136 300
# step_size: 60 27
# windowsize: 90 200
# step_size: 40 18
# Detecting traffic signs:   8%|▊         | 7/87 [03:03<32:10, 24.13s/it]
# []
# 0343.jpg
# imagesize: 750 1000
# windowsize: 675 675
# step_size: 135
# windowsize: 600 600
# step_size: 120
# windowsize: 525 525
# step_size: 105
# windowsize: 450 450
# step_size: 90
# windowsize: 375 375
# step_size: 75
# windowsize: 300 300
# step_size: 60
# windowsize: 225 225
# step_size: 45
# windowsize: 150 150
# step_size: 30
# imagesize: 750 1000
# windowsize: 409 900
# step_size: 180 81
# windowsize: 363 800
# step_size: 160 72
# windowsize: 318 700
# step_size: 140 63
# windowsize: 272 600
# step_size: 120 54
# windowsize: 227 500
# step_size: 100 45
# windowsize: 181 400
# step_size: 80 36
# windowsize: 136 300
# step_size: 60 27
# windowsize: 90 200
# step_size: 40 18
# Detecting traffic signs:   9%|▉         | 8/87 [03:30<33:04, 25.12s/it]
# [(180, 390, 330, 540, 'danger', 0.9698943343015927)]
# 0045.jpg
# imagesize: 750 1000
# windowsize: 675 675
# step_size: 135
# windowsize: 600 600
# step_size: 120
# windowsize: 525 525
# step_size: 105
# windowsize: 450 450
# step_size: 90
# windowsize: 375 375
# step_size: 75
# windowsize: 300 300
# step_size: 60
# windowsize: 225 225
# step_size: 45
# windowsize: 150 150
# step_size: 30
# imagesize: 750 1000
# windowsize: 409 900
# step_size: 180 81
# windowsize: 363 800
# step_size: 160 72
# windowsize: 318 700
# step_size: 140 63
# windowsize: 272 600
# step_size: 120 54
# windowsize: 227 500
# step_size: 100 45
# windowsize: 181 400
# step_size: 80 36
# windowsize: 136 300
# step_size: 60 27
# windowsize: 90 200
# step_size: 40 18
# Detecting traffic signs:  10%|█         | 9/87 [03:57<33:26, 25.72s/it]
# [(240, 360, 390, 510, 'stop', 0.9101472871940989)]
# 0196.jpg
# imagesize: 1000 750
# windowsize: 900 900
# step_size: 180
# windowsize: 800 800
# step_size: 160
# windowsize: 700 700
# step_size: 140
# windowsize: 600 600
# step_size: 120
# windowsize: 500 500
# step_size: 100
# windowsize: 400 400
# step_size: 80
# windowsize: 300 300
# step_size: 60
# windowsize: 200 200
# step_size: 40
# imagesize: 1000 750
# windowsize: 306 675
# step_size: 135 61
# windowsize: 272 600
# step_size: 120 54
# windowsize: 238 525
# step_size: 105 47
# windowsize: 204 450
# step_size: 90 40
# windowsize: 170 375
# step_size: 75 34
# windowsize: 136 300
# step_size: 60 27
# windowsize: 102 225
# step_size: 45 20
# Detecting traffic signs:  11%|█▏        | 10/87 [04:16<29:59, 23.37s/it]
# []
# 0149.jpg
# imagesize: 750 1000
# windowsize: 675 675
# step_size: 135
# windowsize: 600 600
# step_size: 120
# windowsize: 525 525
# step_size: 105
# windowsize: 450 450
# step_size: 90
# windowsize: 375 375
# step_size: 75
# windowsize: 300 300
# step_size: 60
# windowsize: 225 225
# step_size: 45
# windowsize: 150 150
# step_size: 30
# imagesize: 750 1000
# windowsize: 409 900
# step_size: 180 81
# windowsize: 363 800
# step_size: 160 72
# windowsize: 318 700
# step_size: 140 63
# windowsize: 272 600
# step_size: 120 54
# windowsize: 227 500
# step_size: 100 45
# windowsize: 181 400
# step_size: 80 36
# windowsize: 136 300
# step_size: 60 27
# windowsize: 90 200
# step_size: 40 18
# Detecting traffic signs:  13%|█▎        | 11/87 [04:43<31:15, 24.68s/it]
# [(240, 300, 390, 450, 'stop', 0.9104686222268741)]
# 0744.jpg
# imagesize: 1000 1000
# windowsize: 900 900
# step_size: 180
# windowsize: 800 800
# step_size: 160
# windowsize: 700 700
# step_size: 140
# windowsize: 600 600
# step_size: 120
# windowsize: 500 500
# step_size: 100
# windowsize: 400 400
# step_size: 80
# windowsize: 300 300
# step_size: 60
# windowsize: 200 200
# step_size: 40
# imagesize: 1000 1000
# windowsize: 409 900
# step_size: 180 81
# windowsize: 363 800
# step_size: 160 72
# windowsize: 318 700
# step_size: 140 63
# windowsize: 272 600
# step_size: 120 54
# windowsize: 227 500
# step_size: 100 45
# windowsize: 181 400
# step_size: 80 36
# windowsize: 136 300
# step_size: 60 27
# windowsize: 90 200
# step_size: 40 18
# Detecting traffic signs:  14%|█▍        | 12/87 [05:13<32:37, 26.10s/it]
# [(680, 520, 880, 720, 'interdiction', 0.9458307032293004)]
# 0846.jpg
# imagesize: 750 1000
# windowsize: 675 675
# step_size: 135
# windowsize: 600 600
# step_size: 120
# windowsize: 525 525
# step_size: 105
# windowsize: 450 450
# step_size: 90
# windowsize: 375 375
# step_size: 75
# windowsize: 300 300
# step_size: 60
# windowsize: 225 225
# step_size: 45
# windowsize: 150 150
# step_size: 30
# imagesize: 750 1000
# windowsize: 409 900
# step_size: 180 81
# windowsize: 363 800
# step_size: 160 72
# windowsize: 318 700
# step_size: 140 63
# windowsize: 272 600
# step_size: 120 54
# windowsize: 227 500
# step_size: 100 45
# windowsize: 181 400
# step_size: 80 36
# windowsize: 136 300
# step_size: 60 27
# windowsize: 90 200
# step_size: 40 18
# Detecting traffic signs:  15%|█▍        | 13/87 [05:40<32:47, 26.59s/it]
# [(420, 210, 570, 360, 'obligation', 0.9083754175511571), (240, 120, 512, 720, 'fvert', 0.9383005221829219), (200, 100, 427, 600, 'fvert', 0.9328600738197769), (250, 200, 477, 700, 'fvert', 0.9593007977039655), (240, 160, 421, 560, 'fvert', 0.9684949534896586), (280, 160, 461, 560, 'fvert', 0.9646390049295144), (200, 240, 381, 640, 'fvert', 0.9055487491206071), (280, 240, 461, 640, 'fvert', 0.9080697164306987), (390, 60, 526, 360, 'fvert', 0.914692648584287), (420, 60, 556, 360, 'fvert', 0.9590790515719613), (150, 120, 286, 420, 'fvert', 0.928945220906371), (330, 180, 466, 480, 'fvert', 0.9455735228108881), (270, 240, 406, 540, 'fvert', 0.9676368651441684), (300, 240, 436, 540, 'fvert', 0.9820684122078143), (330, 240, 466, 540, 'fvert', 0.9885848857118864), (360, 240, 496, 540, 'fvert', 0.9392677204010588), (330, 300, 466, 600, 'fvert', 0.9326990178409267), (260, 80, 350, 280, 'fvert', 0.9199790242274437), (420, 80, 510, 280, 'fvert', 0.901665111386741), (440, 80, 530, 280, 'fvert', 0.9475033088897765), (340, 120, 430, 320, 'fvert', 0.9159002584867556), (360, 120, 450, 320, 'fvert', 0.9616969444177267), (400, 120, 490, 320, 'fvert', 0.9742368346169956), (420, 120, 510, 320, 'fvert', 0.9276148987052686), (440, 120, 530, 320, 'fvert', 0.9750825620424453), (600, 120, 690, 320, 'fvert', 0.9346597010970218), (260, 160, 350, 360, 'fvert', 0.9612499307276662), (280, 160, 370, 360, 'fvert', 0.9667880742201237), (420, 160, 510, 360, 'fvert', 0.9768767469974663), (440, 160, 530, 360, 'fvert', 0.9594872252606494), (460, 160, 550, 360, 'fvert', 0.9493513288304053), (160, 200, 250, 400, 'fvert', 0.9399335926703876), (180, 200, 270, 400, 'fvert', 0.9617035117865338), (200, 200, 290, 400, 'fvert', 0.9547733352611424), (280, 240, 370, 440, 'fvert', 0.9506954038207391), (300, 240, 390, 440, 'fvert', 0.9436036336108256), (380, 240, 470, 440, 'frouge', 0.9776750721267713), (420, 280, 510, 480, 'frouge', 0.919338368149896), (400, 320, 490, 520, 'fvert', 0.9473067539792895), (420, 320, 510, 520, 'fvert', 0.931187604177059), (40, 480, 130, 680, 'fvert', 0.9416136998163209), (60, 480, 150, 680, 'fvert', 0.9162563518085216)]
# 0325.jpg
# imagesize: 1000 563
# windowsize: 900 900
# step_size: 180
# windowsize: 800 800
# step_size: 160
# windowsize: 700 700
# step_size: 140
# windowsize: 600 600
# step_size: 120
# windowsize: 500 500
# step_size: 100
# windowsize: 400 400
# step_size: 80
# windowsize: 300 300
# step_size: 60
# windowsize: 200 200
# step_size: 40
# imagesize: 1000 563
# windowsize: 229 506
# step_size: 101 45
# windowsize: 204 450
# step_size: 90 40
# windowsize: 179 394
# step_size: 78 35
# windowsize: 153 337
# step_size: 67 30
# windowsize: 127 281
# step_size: 56 25
# windowsize: 102 225
# step_size: 45 20
# Detecting traffic signs:  16%|█▌        | 14/87 [05:54<27:27, 22.57s/it]
# []
# 0395.jpg
# imagesize: 750 1000
# windowsize: 675 675
# step_size: 135
# windowsize: 600 600
# step_size: 120
# windowsize: 525 525
# step_size: 105
# windowsize: 450 450
# step_size: 90
# windowsize: 375 375
# step_size: 75
# windowsize: 300 300
# step_size: 60
# windowsize: 225 225
# step_size: 45
# windowsize: 150 150
# step_size: 30
# imagesize: 750 1000
# windowsize: 409 900
# step_size: 180 81
# windowsize: 363 800
# step_size: 160 72
# windowsize: 318 700
# step_size: 140 63
# windowsize: 272 600
# step_size: 120 54
# windowsize: 227 500
# step_size: 100 45
# windowsize: 181 400
# step_size: 80 36
# windowsize: 136 300
# step_size: 60 27
# windowsize: 90 200
# step_size: 40 18
# Detecting traffic signs:  17%|█▋        | 15/87 [06:21<28:54, 24.09s/it]
# [(270, 180, 495, 405, 'stop', 0.9771407720355748), (220, 520, 310, 720, 'frouge', 0.9447625428752088), (120, 560, 210, 760, 'fvert', 0.9474270038738019), (160, 760, 250, 960, 'fvert', 0.9598749153029863)]
# 0101.jpg
# imagesize: 1000 926
# windowsize: 900 900
# step_size: 180
# windowsize: 800 800
# step_size: 160
# windowsize: 700 700
# step_size: 140
# windowsize: 600 600
# step_size: 120
# windowsize: 500 500
# step_size: 100
# windowsize: 400 400
# step_size: 80
# windowsize: 300 300
# step_size: 60
# windowsize: 200 200
# step_size: 40
# imagesize: 1000 926
# windowsize: 378 833
# step_size: 166 75
# windowsize: 336 740
# step_size: 148 67
# windowsize: 294 648
# step_size: 129 58
# windowsize: 252 555
# step_size: 111 50
# windowsize: 210 463
# step_size: 92 41
# windowsize: 168 370
# step_size: 74 33
# windowsize: 125 277
# step_size: 55 24
# Detecting traffic signs:  18%|█▊        | 16/87 [06:41<27:01, 22.83s/it]
# [(320, 160, 720, 560, 'interdiction', 0.9003190711505362)]
# 0083.jpg
# imagesize: 750 1000
# windowsize: 675 675
# step_size: 135
# windowsize: 600 600
# step_size: 120
# windowsize: 525 525
# step_size: 105
# windowsize: 450 450
# step_size: 90
# windowsize: 375 375
# step_size: 75
# windowsize: 300 300
# step_size: 60
# windowsize: 225 225
# step_size: 45
# windowsize: 150 150
# step_size: 30
# imagesize: 750 1000
# windowsize: 409 900
# step_size: 180 81
# windowsize: 363 800
# step_size: 160 72
# windowsize: 318 700
# step_size: 140 63
# windowsize: 272 600
# step_size: 120 54
# windowsize: 227 500
# step_size: 100 45
# windowsize: 181 400
# step_size: 80 36
# windowsize: 136 300
# step_size: 60 27
# windowsize: 90 200
# step_size: 40 18
# Detecting traffic signs:  20%|█▉        | 17/87 [07:09<28:26, 24.38s/it]
# [(360, 225, 585, 450, 'interdiction', 0.9371072789334595), (270, 330, 420, 480, 'danger', 0.9478635810012396)]
# 0748.jpg
# imagesize: 750 1000
# windowsize: 675 675
# step_size: 135
# windowsize: 600 600
# step_size: 120
# windowsize: 525 525
# step_size: 105
# windowsize: 450 450
# step_size: 90
# windowsize: 375 375
# step_size: 75
# windowsize: 300 300
# step_size: 60
# windowsize: 225 225
# step_size: 45
# windowsize: 150 150
# step_size: 30
# imagesize: 750 1000
# windowsize: 409 900
# step_size: 180 81
# windowsize: 363 800
# step_size: 160 72
# windowsize: 318 700
# step_size: 140 63
# windowsize: 272 600
# step_size: 120 54
# windowsize: 227 500
# step_size: 100 45
# windowsize: 181 400
# step_size: 80 36
# windowsize: 136 300
# step_size: 60 27
# windowsize: 90 200
# step_size: 40 18
# Detecting traffic signs:  21%|██        | 18/87 [07:37<29:17, 25.47s/it]
# [(220, 520, 310, 720, 'frouge', 0.9262636213508949)]
# 0342.jpg
# imagesize: 715 1000
# windowsize: 643 643
# step_size: 128
# windowsize: 572 572
# step_size: 114
# windowsize: 500 500
# step_size: 100
# windowsize: 429 429
# step_size: 85
# windowsize: 357 357
# step_size: 71
# windowsize: 286 286
# step_size: 57
# windowsize: 214 214
# step_size: 42
# imagesize: 715 1000
# windowsize: 409 900
# step_size: 180 81
# windowsize: 363 800
# step_size: 160 72
# windowsize: 318 700
# step_size: 140 63
# windowsize: 272 600
# step_size: 120 54
# windowsize: 227 500
# step_size: 100 45
# windowsize: 181 400
# step_size: 80 36
# windowsize: 136 300
# step_size: 60 27
# windowsize: 90 200
# step_size: 40 18
# Detecting traffic signs:  22%|██▏       | 19/87 [07:57<27:04, 23.89s/it]
# [(360, 320, 541, 720, 'fvert', 0.9031657001268089), (360, 360, 496, 660, 'fvert', 0.9243516218129947), (380, 360, 470, 560, 'fvert', 0.9058122109580228), (420, 360, 510, 560, 'fvert', 0.9233191690474241), (480, 360, 570, 560, 'fvert', 0.9001670869337409), (520, 360, 610, 560, 'fvert', 0.9807589723303017), (540, 360, 630, 560, 'fvert', 0.9897044958897296), (560, 360, 650, 560, 'fvert', 0.9954195040775972), (580, 360, 670, 560, 'fvert', 0.9838219329291921), (460, 400, 550, 600, 'fvert', 0.9026638481616482), (480, 400, 570, 600, 'fvert', 0.908465547961839), (520, 400, 610, 600, 'fvert', 0.932743070229358), (540, 400, 630, 600, 'fvert', 0.9467039895930067), (560, 400, 650, 600, 'fvert', 0.9596902207576298)]
# 0595.jpg
# imagesize: 1000 563
# windowsize: 900 900
# step_size: 180
# windowsize: 800 800
# step_size: 160
# windowsize: 700 700
# step_size: 140
# windowsize: 600 600
# step_size: 120
# windowsize: 500 500
# step_size: 100
# windowsize: 400 400
# step_size: 80
# windowsize: 300 300
# step_size: 60
# windowsize: 200 200
# step_size: 40
# imagesize: 1000 563
# windowsize: 229 506
# step_size: 101 45
# windowsize: 204 450
# step_size: 90 40
# windowsize: 179 394
# step_size: 78 35
# windowsize: 153 337
# step_size: 67 30
# windowsize: 127 281
# step_size: 56 25
# windowsize: 102 225
# step_size: 45 20
# Detecting traffic signs:  23%|██▎       | 20/87 [08:10<23:02, 20.64s/it]
# []
# 0039.jpg
# imagesize: 715 1000
# windowsize: 643 643
# step_size: 128
# windowsize: 572 572
# step_size: 114
# windowsize: 500 500
# step_size: 100
# windowsize: 429 429
# step_size: 85
# windowsize: 357 357
# step_size: 71
# windowsize: 286 286
# step_size: 57
# windowsize: 214 214
# step_size: 42
# imagesize: 715 1000
# windowsize: 409 900
# step_size: 180 81
# windowsize: 363 800
# step_size: 160 72
# windowsize: 318 700
# step_size: 140 63
# windowsize: 272 600
# step_size: 120 54
# windowsize: 227 500
# step_size: 100 45
# windowsize: 181 400
# step_size: 80 36
# windowsize: 136 300
# step_size: 60 27
# windowsize: 90 200
# step_size: 40 18
# Detecting traffic signs:  24%|██▍       | 21/87 [08:31<22:35, 20.53s/it]
# [(114, 285, 400, 571, 'ceder', 0.9669958081018992), (168, 336, 382, 550, 'ceder', 0.9626754875155973)]
# 0871.jpg
# imagesize: 958 1000
# windowsize: 862 862
# step_size: 172
# windowsize: 766 766
# step_size: 153
# windowsize: 670 670
# step_size: 134
# windowsize: 574 574
# step_size: 114
# windowsize: 479 479
# step_size: 95
# windowsize: 383 383
# step_size: 76
# windowsize: 287 287
# step_size: 57
# windowsize: 191 191
# step_size: 38
# imagesize: 958 1000
# windowsize: 409 900
# step_size: 180 81
# windowsize: 363 800
# step_size: 160 72
# windowsize: 318 700
# step_size: 140 63
# windowsize: 272 600
# step_size: 120 54
# windowsize: 227 500
# step_size: 100 45
# windowsize: 181 400
# step_size: 80 36
# windowsize: 136 300
# step_size: 60 27
# windowsize: 90 200
# step_size: 40 18
# Detecting traffic signs:  25%|██▌       | 22/87 [09:01<25:20, 23.39s/it]
# [(399, 114, 686, 401, 'danger', 0.9462138663604129), (399, 627, 686, 914, 'interdiction', 0.981815536671131), (456, 152, 647, 343, 'danger', 0.9371792302044845), (780, 640, 870, 840, 'frouge', 0.9446056256851202), (800, 640, 890, 840, 'frouge', 0.9107896624172879)]
# 0757.jpg
# imagesize: 750 1000
# windowsize: 675 675
# step_size: 135
# windowsize: 600 600
# step_size: 120
# windowsize: 525 525
# step_size: 105
# windowsize: 450 450
# step_size: 90
# windowsize: 375 375
# step_size: 75
# windowsize: 300 300
# step_size: 60
# windowsize: 225 225
# step_size: 45
# windowsize: 150 150
# step_size: 30
# imagesize: 750 1000
# windowsize: 409 900
# step_size: 180 81
# windowsize: 363 800
# step_size: 160 72
# windowsize: 318 700
# step_size: 140 63
# windowsize: 272 600
# step_size: 120 54
# windowsize: 227 500
# step_size: 100 45
# windowsize: 181 400
# step_size: 80 36
# windowsize: 136 300
# step_size: 60 27
# windowsize: 90 200
# step_size: 40 18
# Detecting traffic signs:  26%|██▋       | 23/87 [09:28<26:22, 24.72s/it]
# [(270, 315, 495, 540, 'danger', 0.9130394003926108), (300, 360, 450, 510, 'danger', 0.9931198156623114), (20, 680, 110, 880, 'fvert', 0.9631057733234745), (80, 720, 170, 920, 'frouge', 0.9175862341857267), (0, 760, 90, 960, 'fvert', 0.9090298180651075), (20, 760, 110, 960, 'fvert', 0.9644602913384386), (120, 760, 210, 960, 'frouge', 0.9595565867059619)]
# 0852.jpg
# imagesize: 1000 1000
# windowsize: 900 900
# step_size: 180
# windowsize: 800 800
# step_size: 160
# windowsize: 700 700
# step_size: 140
# windowsize: 600 600
# step_size: 120
# windowsize: 500 500
# step_size: 100
# windowsize: 400 400
# step_size: 80
# windowsize: 300 300
# step_size: 60
# windowsize: 200 200
# step_size: 40
# imagesize: 1000 1000
# windowsize: 409 900
# step_size: 180 81
# windowsize: 363 800
# step_size: 160 72
# windowsize: 318 700
# step_size: 140 63
# windowsize: 272 600
# step_size: 120 54
# windowsize: 227 500
# step_size: 100 45
# windowsize: 181 400
# step_size: 80 36
# windowsize: 136 300
# step_size: 60 27
# windowsize: 90 200
# step_size: 40 18
# Detecting traffic signs:  28%|██▊       | 24/87 [09:58<27:31, 26.21s/it]
# [(400, 240, 600, 440, 'obligation', 0.9447305787606953), (400, 280, 600, 480, 'obligation', 0.9728783220658619), (440, 280, 640, 480, 'obligation', 0.9205784278975387)]
# 0228.jpg
# imagesize: 860 728
# windowsize: 774 774
# step_size: 154
# windowsize: 688 688
# step_size: 137
# windowsize: 602 602
# step_size: 120
# windowsize: 516 516
# step_size: 103
# windowsize: 430 430
# step_size: 86
# windowsize: 344 344
# step_size: 68
# windowsize: 258 258
# step_size: 51
# windowsize: 172 172
# step_size: 34
# imagesize: 860 728
# windowsize: 297 655
# step_size: 131 59
# windowsize: 264 582
# step_size: 116 52
# windowsize: 231 509
# step_size: 101 45
# windowsize: 198 436
# step_size: 87 39
# windowsize: 165 364
# step_size: 72 32
# windowsize: 132 291
# step_size: 58 26
# windowsize: 99 218
# step_size: 43 19
# Detecting traffic signs:  29%|██▊       | 25/87 [10:17<24:47, 23.99s/it]
# [(204, 340, 376, 512, 'danger', 0.9435074148678596)]
# 0831.jpg
# imagesize: 1000 1000
# windowsize: 900 900
# step_size: 180
# windowsize: 800 800
# step_size: 160
# windowsize: 700 700
# step_size: 140
# windowsize: 600 600
# step_size: 120
# windowsize: 500 500
# step_size: 100
# windowsize: 400 400
# step_size: 80
# windowsize: 300 300
# step_size: 60
# windowsize: 200 200
# step_size: 40
# imagesize: 1000 1000
# windowsize: 409 900
# step_size: 180 81
# windowsize: 363 800
# step_size: 160 72
# windowsize: 318 700
# step_size: 140 63
# windowsize: 272 600
# step_size: 120 54
# windowsize: 227 500
# step_size: 100 45
# windowsize: 181 400
# step_size: 80 36
# windowsize: 136 300
# step_size: 60 27
# windowsize: 90 200
# step_size: 40 18
# Detecting traffic signs:  30%|██▉       | 26/87 [10:47<26:22, 25.94s/it]
# [(320, 80, 720, 480, 'obligation', 0.9537758940714421), (320, 160, 720, 560, 'obligation', 0.928819428714775), (360, 60, 660, 360, 'obligation', 0.9138905729289066), (300, 120, 600, 420, 'obligation', 0.9144030092550671), (400, 40, 600, 240, 'obligation', 0.9441108808626114), (360, 80, 560, 280, 'obligation', 0.9650394214582554), (560, 80, 760, 280, 'obligation', 0.9130729607414334), (360, 120, 560, 320, 'obligation', 0.946051368582776), (560, 120, 760, 320, 'obligation', 0.9451464022740702), (320, 160, 520, 360, 'obligation', 0.9685448582587347), (320, 200, 520, 400, 'obligation', 0.9210479089912794), (400, 400, 600, 600, 'obligation', 0.9471772933016697), (750, 100, 977, 600, 'forange', 0.9020595201045655), (760, 80, 941, 480, 'fvert', 0.9517999121764886), (800, 80, 981, 480, 'fvert', 0.9683508587596923), (720, 160, 901, 560, 'forange', 0.9436735774252778), (180, 120, 316, 420, 'frouge', 0.9601804929271356), (210, 120, 346, 420, 'frouge', 0.947281942836499), (840, 180, 976, 480, 'fvert', 0.9032895351245318), (340, 40, 430, 240, 'fvert', 0.9265555794799127), (180, 80, 270, 280, 'frouge', 0.9104287149959279), (260, 80, 350, 280, 'fvert', 0.942189888369957), (180, 160, 270, 360, 'frouge', 0.9222426167698847), (280, 400, 370, 600, 'frouge', 0.9030039104345604)]
# 0710.jpg
# imagesize: 750 1000
# windowsize: 675 675
# step_size: 135
# windowsize: 600 600
# step_size: 120
# windowsize: 525 525
# step_size: 105
# windowsize: 450 450
# step_size: 90
# windowsize: 375 375
# step_size: 75
# windowsize: 300 300
# step_size: 60
# windowsize: 225 225
# step_size: 45
# windowsize: 150 150
# step_size: 30
# imagesize: 750 1000
# windowsize: 409 900
# step_size: 180 81
# windowsize: 363 800
# step_size: 160 72
# windowsize: 318 700
# step_size: 140 63
# windowsize: 272 600
# step_size: 120 54
# windowsize: 227 500
# step_size: 100 45
# windowsize: 181 400
# step_size: 80 36
# windowsize: 136 300
# step_size: 60 27
# windowsize: 90 200
# step_size: 40 18
# Detecting traffic signs:  31%|███       | 27/87 [11:16<26:41, 26.69s/it]
# [(300, 390, 450, 540, 'ceder', 0.983203955816155)]
# 0215.jpg
# imagesize: 1000 750
# windowsize: 900 900
# step_size: 180
# windowsize: 800 800
# step_size: 160
# windowsize: 700 700
# step_size: 140
# windowsize: 600 600
# step_size: 120
# windowsize: 500 500
# step_size: 100
# windowsize: 400 400
# step_size: 80
# windowsize: 300 300
# step_size: 60
# windowsize: 200 200
# step_size: 40
# imagesize: 1000 750
# windowsize: 306 675
# step_size: 135 61
# windowsize: 272 600
# step_size: 120 54
# windowsize: 238 525
# step_size: 105 47
# windowsize: 204 450
# step_size: 90 40
# windowsize: 170 375
# step_size: 75 34
# windowsize: 136 300
# step_size: 60 27
# windowsize: 102 225
# step_size: 45 20
# Detecting traffic signs:  32%|███▏      | 28/87 [11:35<23:59, 24.40s/it]
# [(360, 180, 660, 480, 'ceder', 0.9711289494775328)]
# 0735.jpg
# imagesize: 563 1000
# windowsize: 506 506
# step_size: 101
# windowsize: 450 450
# step_size: 90
# windowsize: 394 394
# step_size: 78
# windowsize: 337 337
# step_size: 67
# windowsize: 281 281
# step_size: 56
# windowsize: 225 225
# step_size: 45
# windowsize: 168 168
# step_size: 33
# imagesize: 563 1000
# windowsize: 409 900
# step_size: 180 81
# windowsize: 363 800
# step_size: 160 72
# windowsize: 318 700
# step_size: 140 63
# windowsize: 272 600
# step_size: 120 54
# windowsize: 227 500
# step_size: 100 45
# windowsize: 181 400
# step_size: 80 36
# windowsize: 136 300
# step_size: 60 27
# windowsize: 90 200
# step_size: 40 18
# Detecting traffic signs:  33%|███▎      | 29/87 [11:54<22:06, 22.87s/it]
# [(112, 224, 393, 505, 'interdiction', 0.9345958625554147), (135, 270, 360, 495, 'interdiction', 0.9422478294278295), (240, 520, 330, 720, 'frouge', 0.9253552066817701)]
# 0272.jpg
# imagesize: 750 1000
# windowsize: 675 675
# step_size: 135
# windowsize: 600 600
# step_size: 120
# windowsize: 525 525
# step_size: 105
# windowsize: 450 450
# step_size: 90
# windowsize: 375 375
# step_size: 75
# windowsize: 300 300
# step_size: 60
# windowsize: 225 225
# step_size: 45
# windowsize: 150 150
# step_size: 30
# imagesize: 750 1000
# windowsize: 409 900
# step_size: 180 81
# windowsize: 363 800
# step_size: 160 72
# windowsize: 318 700
# step_size: 140 63
# windowsize: 272 600
# step_size: 120 54
# windowsize: 227 500
# step_size: 100 45
# windowsize: 181 400
# step_size: 80 36
# windowsize: 136 300
# step_size: 60 27
# windowsize: 90 200
# step_size: 40 18
# Detecting traffic signs:  34%|███▍      | 30/87 [12:22<23:13, 24.45s/it]
# [(405, 315, 630, 540, 'stop', 0.9987387276333601), (480, 360, 630, 510, 'interdiction', 0.9163138803415806)]
# 0652.jpg
# imagesize: 750 1000
# windowsize: 675 675
# step_size: 135
# windowsize: 600 600
# step_size: 120
# windowsize: 525 525
# step_size: 105
# windowsize: 450 450
# step_size: 90
# windowsize: 375 375
# step_size: 75
# windowsize: 300 300
# step_size: 60
# windowsize: 225 225
# step_size: 45
# windowsize: 150 150
# step_size: 30
# imagesize: 750 1000
# windowsize: 409 900
# step_size: 180 81
# windowsize: 363 800
# step_size: 160 72
# windowsize: 318 700
# step_size: 140 63
# windowsize: 272 600
# step_size: 120 54
# windowsize: 227 500
# step_size: 100 45
# windowsize: 181 400
# step_size: 80 36
# windowsize: 136 300
# step_size: 60 27
# windowsize: 90 200
# step_size: 40 18
# Detecting traffic signs:  36%|███▌      | 31/87 [12:50<23:49, 25.52s/it]
# [(300, 480, 436, 780, 'frouge', 0.9494311871286983), (340, 560, 430, 760, 'fvert', 0.9472599865837557), (360, 560, 450, 760, 'fvert', 0.9649199113290096), (380, 560, 470, 760, 'fvert', 0.9515643848904968), (320, 600, 410, 800, 'forange', 0.9577706154871852), (340, 600, 430, 800, 'forange', 0.9957817362825728), (360, 600, 450, 800, 'forange', 0.9908403870617877), (340, 680, 430, 880, 'frouge', 0.9468070268701799), (360, 720, 450, 920, 'fvert', 0.9012663654086892), (380, 720, 470, 920, 'fvert', 0.9749448033262734), (40, 760, 130, 960, 'forange', 0.9139511068699528)]
# 0229.jpg
# imagesize: 750 1000
# windowsize: 675 675
# step_size: 135
# windowsize: 600 600
# step_size: 120
# windowsize: 525 525
# step_size: 105
# windowsize: 450 450
# step_size: 90
# windowsize: 375 375
# step_size: 75
# windowsize: 300 300
# step_size: 60
# windowsize: 225 225
# step_size: 45
# windowsize: 150 150
# step_size: 30
# imagesize: 750 1000
# windowsize: 409 900
# step_size: 180 81
# windowsize: 363 800
# step_size: 160 72
# windowsize: 318 700
# step_size: 140 63
# windowsize: 272 600
# step_size: 120 54
# windowsize: 227 500
# step_size: 100 45
# windowsize: 181 400
# step_size: 80 36
# windowsize: 136 300
# step_size: 60 27
# windowsize: 90 200
# step_size: 40 18
# Detecting traffic signs:  37%|███▋      | 32/87 [13:20<24:23, 26.60s/it]
# []
# 0691.jpg
# imagesize: 1000 535
# windowsize: 900 900
# step_size: 180
# windowsize: 800 800
# step_size: 160
# windowsize: 700 700
# step_size: 140
# windowsize: 600 600
# step_size: 120
# windowsize: 500 500
# step_size: 100
# windowsize: 400 400
# step_size: 80
# windowsize: 300 300
# step_size: 60
# windowsize: 200 200
# step_size: 40
# imagesize: 1000 535
# windowsize: 218 481
# step_size: 96 43
# windowsize: 194 428
# step_size: 85 38
# windowsize: 170 374
# step_size: 74 33
# windowsize: 145 321
# step_size: 64 29
# windowsize: 121 267
# step_size: 53 24
# windowsize: 97 214
# step_size: 42 19
# Detecting traffic signs:  38%|███▊      | 33/87 [13:33<20:29, 22.77s/it]
# []
# 0681.jpg
# imagesize: 750 1000
# windowsize: 675 675
# step_size: 135
# windowsize: 600 600
# step_size: 120
# windowsize: 525 525
# step_size: 105
# windowsize: 450 450
# step_size: 90
# windowsize: 375 375
# step_size: 75
# windowsize: 300 300
# step_size: 60
# windowsize: 225 225
# step_size: 45
# windowsize: 150 150
# step_size: 30
# imagesize: 750 1000
# windowsize: 409 900
# step_size: 180 81
# windowsize: 363 800
# step_size: 160 72
# windowsize: 318 700
# step_size: 140 63
# windowsize: 272 600
# step_size: 120 54
# windowsize: 227 500
# step_size: 100 45
# windowsize: 181 400
# step_size: 80 36
# windowsize: 136 300
# step_size: 60 27
# windowsize: 90 200
# step_size: 40 18
# Detecting traffic signs:  39%|███▉      | 34/87 [14:02<21:43, 24.60s/it]
# []
# 0617.jpg
# imagesize: 750 1000
# windowsize: 675 675
# step_size: 135
# windowsize: 600 600
# step_size: 120
# windowsize: 525 525
# step_size: 105
# windowsize: 450 450
# step_size: 90
# windowsize: 375 375
# step_size: 75
# windowsize: 300 300
# step_size: 60
# windowsize: 225 225
# step_size: 45
# windowsize: 150 150
# step_size: 30
# imagesize: 750 1000
# windowsize: 409 900
# step_size: 180 81
# windowsize: 363 800
# step_size: 160 72
# windowsize: 318 700
# step_size: 140 63
# windowsize: 272 600
# step_size: 120 54
# windowsize: 227 500
# step_size: 100 45
# windowsize: 181 400
# step_size: 80 36
# windowsize: 136 300
# step_size: 60 27
# windowsize: 90 200
# step_size: 40 18
# Detecting traffic signs:  40%|████      | 35/87 [14:30<22:03, 25.45s/it]
# []
# 0864.jpg
# imagesize: 762 1000
# windowsize: 685 685
# step_size: 137
# windowsize: 609 609
# step_size: 121
# windowsize: 533 533
# step_size: 106
# windowsize: 457 457
# step_size: 91
# windowsize: 381 381
# step_size: 76
# windowsize: 304 304
# step_size: 60
# windowsize: 228 228
# step_size: 45
# windowsize: 152 152
# step_size: 30
# imagesize: 762 1000
# windowsize: 409 900
# step_size: 180 81
# windowsize: 363 800
# step_size: 160 72
# windowsize: 318 700
# step_size: 140 63
# windowsize: 272 600
# step_size: 120 54
# windowsize: 227 500
# step_size: 100 45
# windowsize: 181 400
# step_size: 80 36
# windowsize: 136 300
# step_size: 60 27
# windowsize: 90 200
# step_size: 40 18
# Detecting traffic signs:  41%|████▏     | 36/87 [14:57<22:13, 26.14s/it]
# [(360, 90, 588, 318, 'stop', 0.9906680712005085)]
# 0216.jpg
# imagesize: 563 1000
# windowsize: 506 506
# step_size: 101
# windowsize: 450 450
# step_size: 90
# windowsize: 394 394
# step_size: 78
# windowsize: 337 337
# step_size: 67
# windowsize: 281 281
# step_size: 56
# windowsize: 225 225
# step_size: 45
# windowsize: 168 168
# step_size: 33
# imagesize: 563 1000
# windowsize: 409 900
# step_size: 180 81
# windowsize: 363 800
# step_size: 160 72
# windowsize: 318 700
# step_size: 140 63
# windowsize: 272 600
# step_size: 120 54
# windowsize: 227 500
# step_size: 100 45
# windowsize: 181 400
# step_size: 80 36
# windowsize: 136 300
# step_size: 60 27
# windowsize: 90 200
# step_size: 40 18
# Detecting traffic signs:  43%|████▎     | 37/87 [15:16<19:59, 23.99s/it]
# [(78, 78, 472, 472, 'interdiction', 0.9212543737963662)]
# 0547.jpg
# imagesize: 1000 1000
# windowsize: 900 900
# step_size: 180
# windowsize: 800 800
# step_size: 160
# windowsize: 700 700
# step_size: 140
# windowsize: 600 600
# step_size: 120
# windowsize: 500 500
# step_size: 100
# windowsize: 400 400
# step_size: 80
# windowsize: 300 300
# step_size: 60
# windowsize: 200 200
# step_size: 40
# imagesize: 1000 1000
# windowsize: 409 900
# step_size: 180 81
# windowsize: 363 800
# step_size: 160 72
# windowsize: 318 700
# step_size: 140 63
# windowsize: 272 600
# step_size: 120 54
# windowsize: 227 500
# step_size: 100 45
# windowsize: 181 400
# step_size: 80 36
# windowsize: 136 300
# step_size: 60 27
# windowsize: 90 200
# step_size: 40 18
# Detecting traffic signs:  44%|████▎     | 38/87 [15:46<20:54, 25.61s/it]
# [(0, 0, 409, 900, 'fvert', 0.9418882396745476), (0, 0, 363, 800, 'fvert', 0.9528981829840432), (0, 140, 318, 840, 'fvert', 0.9877657845676061), (70, 140, 388, 840, 'fvert', 0.9514882077294681), (180, 0, 452, 600, 'fvert', 0.9307767974942499), (0, 240, 272, 840, 'fvert', 0.9787730497237646), (60, 240, 332, 840, 'fvert', 0.9619313889221205), (720, 240, 992, 840, 'forange', 0.9472186059724265), (50, 0, 277, 500, 'fvert', 0.9938808102686302), (100, 100, 327, 600, 'fvert', 0.9363531723089201), (200, 200, 427, 700, 'forange', 0.9843214278479362), (250, 200, 477, 700, 'forange', 0.9703194276840413), (0, 300, 227, 800, 'fvert', 0.9943459818018283), (50, 300, 277, 800, 'fvert', 0.99305416043027), (100, 300, 327, 800, 'fvert', 0.9789132807312944), (120, 0, 301, 400, 'fvert', 0.9962446310780526), (200, 0, 381, 400, 'forange', 0.9260825659880534), (280, 0, 461, 400, 'forange', 0.9094704039657847), (600, 0, 781, 400, 'forange', 0.9567328959231609), (680, 0, 861, 400, 'fvert', 0.9297189118869881), (720, 0, 901, 400, 'fvert', 0.9260780923132423), (120, 160, 301, 560, 'fvert', 0.9547775322422138), (760, 160, 941, 560, 'fvert', 0.9280661343280832), (240, 240, 421, 640, 'forange', 0.9831835660003878), (280, 240, 461, 640, 'forange', 0.9021812930707317), (0, 320, 181, 720, 'fvert', 0.9670467199785039), (40, 320, 221, 720, 'fvert', 0.9843550733664551), (80, 320, 261, 720, 'fvert', 0.9961555251818984), (120, 320, 301, 720, 'fvert', 0.993563267042554), (160, 320, 341, 720, 'fvert', 0.9114396294571185), (40, 400, 221, 800, 'fvert', 0.9740026553012145), (80, 400, 261, 800, 'fvert', 0.9371942373402747), (120, 400, 301, 800, 'fvert', 0.9132890511493992), (210, 60, 346, 360, 'fvert', 0.9227119180426712), (150, 120, 286, 420, 'fvert', 0.9595972478239758), (300, 120, 436, 420, 'frouge', 0.9671797301703546), (540, 120, 676, 420, 'frouge', 0.9842195898956463), (570, 120, 706, 420, 'frouge', 0.9174833767214788), (690, 120, 826, 420, 'forange', 0.9240562479038503), (180, 180, 316, 480, 'fvert', 0.915774445882815), (570, 180, 706, 480, 'fvert', 0.9117254544979391), (600, 180, 736, 480, 'fvert', 0.9232178283265084), (750, 180, 886, 480, 'fvert', 0.934719656600767), (780, 180, 916, 480, 'fvert', 0.9694128848133049), (810, 180, 946, 480, 'fvert', 0.9233760105577024), (840, 180, 976, 480, 'fvert', 0.9279134280562797), (300, 240, 436, 540, 'forange', 0.9125883037310711), (810, 240, 946, 540, 'fvert', 0.924442306899395), (180, 300, 316, 600, 'forange', 0.9171668038223847), (240, 300, 376, 600, 'forange', 0.9724420274671961), (90, 360, 226, 660, 'fvert', 0.9193959765906367), (120, 360, 256, 660, 'fvert', 0.9859270602529204), (150, 360, 286, 660, 'fvert', 0.9432525155407514), (180, 360, 316, 660, 'fvert', 0.9236358596019075), (690, 360, 826, 660, 'fvert', 0.9554895406980937), (0, 420, 136, 720, 'fvert', 0.9686130441242651), (30, 420, 166, 720, 'fvert', 0.9835781317416863), (60, 420, 196, 720, 'fvert', 0.9836865542546606), (90, 420, 226, 720, 'fvert', 0.9963700475786159), (120, 420, 256, 720, 'fvert', 0.9903550928187337), (150, 420, 286, 720, 'fvert', 0.9713712157199995), (180, 420, 316, 720, 'fvert', 0.9698603142998774), (0, 480, 136, 780, 'fvert', 0.9280296027304522), (260, 120, 350, 320, 'fvert', 0.9066871901220513), (300, 200, 390, 400, 'frouge', 0.9072005152612825), (320, 200, 410, 400, 'frouge', 0.9360094254636954), (340, 200, 430, 400, 'frouge', 0.9406217528480055), (360, 200, 450, 400, 'frouge', 0.9466706461224521), (560, 200, 650, 400, 'frouge', 0.9409572799198829), (700, 200, 790, 400, 'fvert', 0.982384393803931), (800, 200, 890, 400, 'fvert', 0.9088518803059223), (560, 240, 650, 440, 'frouge', 0.9185572071647099), (620, 240, 710, 440, 'fvert', 0.9798102041597138), (640, 240, 730, 440, 'fvert', 0.9909972076848875), (660, 240, 750, 440, 'fvert', 0.9246773733328625), (820, 240, 910, 440, 'fvert', 0.9832866145981248), (840, 240, 930, 440, 'fvert', 0.9802399786205219), (860, 240, 950, 440, 'fvert', 0.9320266070418415), (880, 240, 970, 440, 'fvert', 0.951664706398 ...
# 0145.jpg
# imagesize: 687 1000
# windowsize: 618 618
# step_size: 123
# windowsize: 549 549
# step_size: 109
# windowsize: 480 480
# step_size: 96
# windowsize: 412 412
# step_size: 82
# windowsize: 343 343
# step_size: 68
# windowsize: 274 274
# step_size: 54
# windowsize: 206 206
# step_size: 41
# imagesize: 687 1000
# windowsize: 409 900
# step_size: 180 81
# windowsize: 363 800
# step_size: 160 72
# windowsize: 318 700
# step_size: 140 63
# windowsize: 272 600
# step_size: 120 54
# windowsize: 227 500
# step_size: 100 45
# windowsize: 181 400
# step_size: 80 36
# windowsize: 136 300
# step_size: 60 27
# windowsize: 90 200
# step_size: 40 18
# Detecting traffic signs:  45%|████▍     | 39/87 [16:05<19:03, 23.83s/it]
# [(260, 240, 350, 440, 'frouge', 0.9062150655069869), (260, 280, 350, 480, 'frouge', 0.9188748366508149)]
# 0479.jpg
# imagesize: 750 1000
# windowsize: 675 675
# step_size: 135
# windowsize: 600 600
# step_size: 120
# windowsize: 525 525
# step_size: 105
# windowsize: 450 450
# step_size: 90
# windowsize: 375 375
# step_size: 75
# windowsize: 300 300
# step_size: 60
# windowsize: 225 225
# step_size: 45
# windowsize: 150 150
# step_size: 30
# imagesize: 750 1000
# windowsize: 409 900
# step_size: 180 81
# windowsize: 363 800
# step_size: 160 72
# windowsize: 318 700
# step_size: 140 63
# windowsize: 272 600
# step_size: 120 54
# windowsize: 227 500
# step_size: 100 45
# windowsize: 181 400
# step_size: 80 36
# windowsize: 136 300
# step_size: 60 27
# windowsize: 90 200
# step_size: 40 18
# Detecting traffic signs:  46%|████▌     | 40/87 [16:33<19:37, 25.04s/it]
# [(270, 225, 495, 450, 'danger', 0.9533824104443431), (270, 270, 495, 495, 'danger', 0.9152829824787759), (320, 0, 410, 200, 'forange', 0.9304885942310124), (340, 0, 430, 200, 'forange', 0.9251001990686636), (340, 40, 430, 240, 'frouge', 0.9747292403948832), (360, 120, 450, 320, 'fvert', 0.9405700354187669), (280, 560, 370, 760, 'fvert', 0.9147139584847359)]
# 0054.jpg
# imagesize: 750 1000
# windowsize: 675 675
# step_size: 135
# windowsize: 600 600
# step_size: 120
# windowsize: 525 525
# step_size: 105
# windowsize: 450 450
# step_size: 90
# windowsize: 375 375
# step_size: 75
# windowsize: 300 300
# step_size: 60
# windowsize: 225 225
# step_size: 45
# windowsize: 150 150
# step_size: 30
# imagesize: 750 1000
# windowsize: 409 900
# step_size: 180 81
# windowsize: 363 800
# step_size: 160 72
# windowsize: 318 700
# step_size: 140 63
# windowsize: 272 600
# step_size: 120 54
# windowsize: 227 500
# step_size: 100 45
# windowsize: 181 400
# step_size: 80 36
# windowsize: 136 300
# step_size: 60 27
# windowsize: 90 200
# step_size: 40 18
# Detecting traffic signs:  47%|████▋     | 41/87 [17:01<19:52, 25.93s/it]
# [(360, 390, 510, 540, 'obligation', 0.9169329218724753), (390, 390, 540, 540, 'obligation', 0.9035651254012745)]
# 0834.jpg
# imagesize: 750 1000
# windowsize: 675 675
# step_size: 135
# windowsize: 600 600
# step_size: 120
# windowsize: 525 525
# step_size: 105
# windowsize: 450 450
# step_size: 90
# windowsize: 375 375
# step_size: 75
# windowsize: 300 300
# step_size: 60
# windowsize: 225 225
# step_size: 45
# windowsize: 150 150
# step_size: 30
# imagesize: 750 1000
# windowsize: 409 900
# step_size: 180 81
# windowsize: 363 800
# step_size: 160 72
# windowsize: 318 700
# step_size: 140 63
# windowsize: 272 600
# step_size: 120 54
# windowsize: 227 500
# step_size: 100 45
# windowsize: 181 400
# step_size: 80 36
# windowsize: 136 300
# step_size: 60 27
# windowsize: 90 200
# step_size: 40 18
# Detecting traffic signs:  48%|████▊     | 42/87 [17:29<19:52, 26.51s/it]
# [(225, 270, 450, 495, 'interdiction', 0.9762309014200017), (270, 270, 495, 495, 'interdiction', 0.9006528432448054), (270, 315, 495, 540, 'interdiction', 0.9364268311415404), (360, 360, 510, 510, 'interdiction', 0.9002231294575874), (180, 390, 330, 540, 'danger', 0.9285349734323441), (160, 0, 523, 800, 'forange', 0.9398090876967727), (180, 120, 452, 720, 'forange', 0.941469103264177), (560, 0, 741, 400, 'fvert', 0.9060566716891232), (600, 60, 736, 360, 'fvert', 0.9166421825024063), (560, 40, 650, 240, 'fvert', 0.9774099552066426), (580, 40, 670, 240, 'fvert', 0.9101668259696967), (600, 40, 690, 240, 'fvert', 0.9594500082838129), (620, 40, 710, 240, 'fvert', 0.9263419654032536), (640, 40, 730, 240, 'fvert', 0.9427782114149867), (540, 80, 630, 280, 'fvert', 0.93004888987914), (560, 80, 650, 280, 'fvert', 0.9166259904908423), (580, 80, 670, 280, 'fvert', 0.937904490572032), (600, 80, 690, 280, 'fvert', 0.9587128268192855), (620, 80, 710, 280, 'fvert', 0.9483688454600311), (640, 80, 730, 280, 'fvert', 0.9469940634832871), (600, 120, 690, 320, 'fvert', 0.9026269712328501), (280, 360, 370, 560, 'frouge', 0.9597962719755649)]
# 0291.jpg
# imagesize: 750 1000
# windowsize: 675 675
# step_size: 135
# windowsize: 600 600
# step_size: 120
# windowsize: 525 525
# step_size: 105
# windowsize: 450 450
# step_size: 90
# windowsize: 375 375
# step_size: 75
# windowsize: 300 300
# step_size: 60
# windowsize: 225 225
# step_size: 45
# windowsize: 150 150
# step_size: 30
# imagesize: 750 1000
# windowsize: 409 900
# step_size: 180 81
# windowsize: 363 800
# step_size: 160 72
# windowsize: 318 700
# step_size: 140 63
# windowsize: 272 600
# step_size: 120 54
# windowsize: 227 500
# step_size: 100 45
# windowsize: 181 400
# step_size: 80 36
# windowsize: 136 300
# step_size: 60 27
# windowsize: 90 200
# step_size: 40 18
# Detecting traffic signs:  49%|████▉     | 43/87 [17:57<19:42, 26.87s/it]
# [(120, 120, 720, 720, 'ceder', 0.9578278121648707), (105, 210, 630, 735, 'ceder', 0.9826445412861508), (180, 270, 630, 720, 'ceder', 0.9357259440556683), (120, 420, 420, 720, 'danger', 0.9239229108791017), (135, 405, 360, 630, 'danger', 0.9513142167669917), (135, 450, 360, 675, 'danger', 0.9425733527779874), (330, 420, 480, 570, 'ceder', 0.916310546943009), (180, 450, 330, 600, 'danger', 0.9652424493174422), (210, 480, 360, 630, 'danger', 0.9212279736395141), (210, 510, 360, 660, 'danger', 0.9548014733227491), (210, 540, 360, 690, 'danger', 0.9157244474335199), (240, 540, 390, 690, 'danger', 0.9580011758276019), (240, 570, 390, 720, 'danger', 0.947125665329421), (270, 600, 420, 750, 'danger', 0.9432376247576355), (330, 600, 480, 750, 'ceder', 0.9154463370945517)]
# 0413.jpg
# imagesize: 1000 563
# windowsize: 900 900
# step_size: 180
# windowsize: 800 800
# step_size: 160
# windowsize: 700 700
# step_size: 140
# windowsize: 600 600
# step_size: 120
# windowsize: 500 500
# step_size: 100
# windowsize: 400 400
# step_size: 80
# windowsize: 300 300
# step_size: 60
# windowsize: 200 200
# step_size: 40
# imagesize: 1000 563
# windowsize: 229 506
# step_size: 101 45
# windowsize: 204 450
# step_size: 90 40
# windowsize: 179 394
# step_size: 78 35
# windowsize: 153 337
# step_size: 67 30
# windowsize: 127 281
# step_size: 56 25
# windowsize: 102 225
# step_size: 45 20
# Detecting traffic signs:  51%|█████     | 44/87 [18:10<16:20, 22.80s/it]
# []
# 0709.jpg
# imagesize: 750 1000
# windowsize: 675 675
# step_size: 135
# windowsize: 600 600
# step_size: 120
# windowsize: 525 525
# step_size: 105
# windowsize: 450 450
# step_size: 90
# windowsize: 375 375
# step_size: 75
# windowsize: 300 300
# step_size: 60
# windowsize: 225 225
# step_size: 45
# windowsize: 150 150
# step_size: 30
# imagesize: 750 1000
# windowsize: 409 900
# step_size: 180 81
# windowsize: 363 800
# step_size: 160 72
# windowsize: 318 700
# step_size: 140 63
# windowsize: 272 600
# step_size: 120 54
# windowsize: 227 500
# step_size: 100 45
# windowsize: 181 400
# step_size: 80 36
# windowsize: 136 300
# step_size: 60 27
# windowsize: 90 200
# step_size: 40 18
# Detecting traffic signs:  52%|█████▏    | 45/87 [18:38<17:02, 24.35s/it]
# [(300, 300, 450, 450, 'ceder', 0.9353898092053194), (320, 120, 410, 320, 'fvert', 0.9079680345672132)]
# 0444.jpg
# imagesize: 750 1000
# windowsize: 675 675
# step_size: 135
# windowsize: 600 600
# step_size: 120
# windowsize: 525 525
# step_size: 105
# windowsize: 450 450
# step_size: 90
# windowsize: 375 375
# step_size: 75
# windowsize: 300 300
# step_size: 60
# windowsize: 225 225
# step_size: 45
# windowsize: 150 150
# step_size: 30
# imagesize: 750 1000
# windowsize: 409 900
# step_size: 180 81
# windowsize: 363 800
# step_size: 160 72
# windowsize: 318 700
# step_size: 140 63
# windowsize: 272 600
# step_size: 120 54
# windowsize: 227 500
# step_size: 100 45
# windowsize: 181 400
# step_size: 80 36
# windowsize: 136 300
# step_size: 60 27
# windowsize: 90 200
# step_size: 40 18
# ...
# step_size: 40
# imagesize: 1000 1000
# windowsize: 409 900
# step_size: 180 81
# windowsize: 363 800
# step_size: 160 72
# windowsize: 318 700
# step_size: 140 63
# windowsize: 272 600
# step_size: 120 54
# windowsize: 227 500
# step_size: 100 45
# windowsize: 181 400
# step_size: 80 36
# windowsize: 136 300
# step_size: 60 27
# windowsize: 90 200
# step_size: 40 18
# Detecting traffic signs:  80%|████████  | 70/87 [29:07<08:17, 29.26s/it]
# [(300, 120, 600, 420, 'ceder', 0.9032763117254242), (360, 160, 560, 360, 'ceder', 0.991620958770714), (400, 160, 600, 360, 'ceder', 0.9873731599874559), (150, 480, 286, 780, 'forange', 0.9067412686503764), (80, 560, 170, 760, 'forange', 0.9385733579560828)]
# 0132.jpg
# imagesize: 1000 563
# windowsize: 900 900
# step_size: 180
# windowsize: 800 800
# step_size: 160
# windowsize: 700 700
# step_size: 140
# windowsize: 600 600
# step_size: 120
# windowsize: 500 500
# step_size: 100
# windowsize: 400 400
# step_size: 80
# windowsize: 300 300
# step_size: 60
# windowsize: 200 200
# step_size: 40
# imagesize: 1000 563
# windowsize: 229 506
# step_size: 101 45
# windowsize: 204 450
# step_size: 90 40
# windowsize: 179 394
# step_size: 78 35
# windowsize: 153 337
# step_size: 67 30
# windowsize: 127 281
# step_size: 56 25
# windowsize: 102 225
# step_size: 45 20
# Detecting traffic signs:  82%|████████▏ | 71/87 [29:22<06:42, 25.14s/it]
# [(0, 40, 200, 240, 'danger', 0.9241097008412004)]
# 0766.jpg
# imagesize: 750 1000
# windowsize: 675 675
# step_size: 135
# windowsize: 600 600
# step_size: 120
# windowsize: 525 525
# step_size: 105
# windowsize: 450 450
# step_size: 90
# windowsize: 375 375
# step_size: 75
# windowsize: 300 300
# step_size: 60
# windowsize: 225 225
# step_size: 45
# windowsize: 150 150
# step_size: 30
# imagesize: 750 1000
# windowsize: 409 900
# step_size: 180 81
# windowsize: 363 800
# step_size: 160 72
# windowsize: 318 700
# step_size: 140 63
# windowsize: 272 600
# step_size: 120 54
# windowsize: 227 500
# step_size: 100 45
# windowsize: 181 400
# step_size: 80 36
# windowsize: 136 300
# step_size: 60 27
# windowsize: 90 200
# step_size: 40 18
# Detecting traffic signs:  83%|████████▎ | 72/87 [29:55<06:49, 27.27s/it]
# []
# 0428.jpg
# imagesize: 751 1000
# windowsize: 675 675
# step_size: 135
# windowsize: 600 600
# step_size: 120
# windowsize: 525 525
# step_size: 105
# windowsize: 450 450
# step_size: 90
# windowsize: 375 375
# step_size: 75
# windowsize: 300 300
# step_size: 60
# windowsize: 225 225
# step_size: 45
# windowsize: 150 150
# step_size: 30
# imagesize: 751 1000
# windowsize: 409 900
# step_size: 180 81
# windowsize: 363 800
# step_size: 160 72
# windowsize: 318 700
# step_size: 140 63
# windowsize: 272 600
# step_size: 120 54
# windowsize: 227 500
# step_size: 100 45
# windowsize: 181 400
# step_size: 80 36
# windowsize: 136 300
# step_size: 60 27
# windowsize: 90 200
# step_size: 40 18
# Detecting traffic signs:  84%|████████▍ | 73/87 [30:26<06:40, 28.59s/it]
# [(360, 360, 450, 560, 'forange', 0.946797931649865)]
# 0270.jpg
# imagesize: 807 1000
# windowsize: 726 726
# step_size: 145
# windowsize: 645 645
# step_size: 129
# windowsize: 564 564
# step_size: 112
# windowsize: 484 484
# step_size: 96
# windowsize: 403 403
# step_size: 80
# windowsize: 322 322
# step_size: 64
# windowsize: 242 242
# step_size: 48
# windowsize: 161 161
# step_size: 32
# imagesize: 807 1000
# windowsize: 409 900
# step_size: 180 81
# windowsize: 363 800
# step_size: 160 72
# windowsize: 318 700
# step_size: 140 63
# windowsize: 272 600
# step_size: 120 54
# windowsize: 227 500
# step_size: 100 45
# windowsize: 181 400
# step_size: 80 36
# windowsize: 136 300
# step_size: 60 27
# windowsize: 90 200
# step_size: 40 18
# Detecting traffic signs:  85%|████████▌ | 74/87 [30:57<06:19, 29.19s/it]
# [(448, 64, 770, 386, 'interdiction', 0.9699994975211991), (448, 192, 770, 514, 'interdiction', 0.9172264989648217), (528, 48, 770, 290, 'interdiction', 0.9794427220737953), (576, 64, 737, 225, 'interdiction', 0.9110676086614479), (448, 256, 609, 417, 'interdiction', 0.9191429559299482)]
# 0568.jpg
# imagesize: 936 1000
# windowsize: 842 842
# step_size: 168
# windowsize: 748 748
# step_size: 149
# windowsize: 655 655
# step_size: 131
# windowsize: 561 561
# step_size: 112
# windowsize: 468 468
# step_size: 93
# windowsize: 374 374
# step_size: 74
# windowsize: 280 280
# step_size: 56
# windowsize: 187 187
# step_size: 37
# imagesize: 936 1000
# windowsize: 409 900
# step_size: 180 81
# windowsize: 363 800
# step_size: 160 72
# windowsize: 318 700
# step_size: 140 63
# windowsize: 272 600
# step_size: 120 54
# windowsize: 227 500
# step_size: 100 45
# windowsize: 181 400
# step_size: 80 36
# windowsize: 136 300
# step_size: 60 27
# windowsize: 90 200
# step_size: 40 18
# Detecting traffic signs:  86%|████████▌ | 75/87 [31:29<05:59, 29.95s/it]
# [(336, 336, 616, 616, 'obligation', 0.9085938948779438), (370, 333, 557, 520, 'obligation', 0.9472832082459043), (370, 370, 557, 557, 'obligation', 0.9969658885393641), (360, 240, 541, 640, 'forange', 0.9060413779241671)]
# 0698.jpg
# imagesize: 473 1000
# windowsize: 425 425
# step_size: 85
# windowsize: 378 378
# step_size: 75
# windowsize: 331 331
# step_size: 66
# windowsize: 283 283
# step_size: 56
# windowsize: 236 236
# step_size: 47
# windowsize: 189 189
# step_size: 37
# imagesize: 473 1000
# windowsize: 409 900
# step_size: 180 81
# windowsize: 363 800
# step_size: 160 72
# windowsize: 318 700
# step_size: 140 63
# windowsize: 272 600
# step_size: 120 54
# windowsize: 227 500
# step_size: 100 45
# windowsize: 181 400
# step_size: 80 36
# windowsize: 136 300
# step_size: 60 27
# windowsize: 90 200
# step_size: 40 18
# Detecting traffic signs:  87%|████████▋ | 76/87 [31:44<04:40, 25.49s/it]
# [(112, 224, 395, 507, 'ceder', 0.9397322378533861), (141, 235, 377, 471, 'ceder', 0.9660226447990717), (148, 259, 337, 448, 'ceder', 0.9095023221933529), (185, 259, 374, 448, 'ceder', 0.952578703599901), (185, 296, 374, 485, 'ceder', 0.9234335378776684)]
# 0406.jpg
# imagesize: 750 1000
# windowsize: 675 675
# step_size: 135
# windowsize: 600 600
# step_size: 120
# windowsize: 525 525
# step_size: 105
# windowsize: 450 450
# step_size: 90
# windowsize: 375 375
# step_size: 75
# windowsize: 300 300
# step_size: 60
# windowsize: 225 225
# step_size: 45
# windowsize: 150 150
# step_size: 30
# imagesize: 750 1000
# windowsize: 409 900
# step_size: 180 81
# windowsize: 363 800
# step_size: 160 72
# windowsize: 318 700
# step_size: 140 63
# windowsize: 272 600
# step_size: 120 54
# windowsize: 227 500
# step_size: 100 45
# windowsize: 181 400
# step_size: 80 36
# windowsize: 136 300
# step_size: 60 27
# windowsize: 90 200
# step_size: 40 18
# Detecting traffic signs:  89%|████████▊ | 77/87 [32:15<04:30, 27.09s/it]
# [(360, 240, 496, 540, 'fvert', 0.9623518895747307), (390, 240, 526, 540, 'fvert', 0.9619745512928305), (360, 360, 496, 660, 'fvert', 0.9316825197380956), (440, 40, 530, 240, 'forange', 0.949793205078737), (360, 240, 450, 440, 'frouge', 0.9074282399344598), (380, 280, 470, 480, 'fvert', 0.9839937067460947), (400, 280, 490, 480, 'fvert', 0.9963296820065666), (420, 280, 510, 480, 'fvert', 0.9221441823420345), (400, 320, 490, 520, 'fvert', 0.9855953205425441), (420, 320, 510, 520, 'fvert', 0.9211877050571771), (380, 360, 470, 560, 'forange', 0.9841301768663216), (400, 360, 490, 560, 'forange', 0.9437607426345084), (360, 400, 450, 600, 'fvert', 0.9229547727100698)]
# 0839.jpg
# imagesize: 1000 1000
# windowsize: 900 900
# step_size: 180
# windowsize: 800 800
# step_size: 160
# windowsize: 700 700
# step_size: 140
# windowsize: 600 600
# step_size: 120
# windowsize: 500 500
# step_size: 100
# windowsize: 400 400
# step_size: 80
# windowsize: 300 300
# step_size: 60
# windowsize: 200 200
# step_size: 40
# imagesize: 1000 1000
# windowsize: 409 900
# step_size: 180 81
# windowsize: 363 800
# step_size: 160 72
# windowsize: 318 700
# step_size: 140 63
# windowsize: 272 600
# step_size: 120 54
# windowsize: 227 500
# step_size: 100 45
# windowsize: 181 400
# step_size: 80 36
# windowsize: 136 300
# step_size: 60 27
# windowsize: 90 200
# step_size: 40 18
# Detecting traffic signs:  90%|████████▉ | 78/87 [32:47<04:18, 28.71s/it]
# [(320, 280, 410, 480, 'frouge', 0.9599383718099903), (360, 280, 450, 480, 'frouge', 0.9114670007342656), (320, 320, 410, 520, 'frouge', 0.9200025712761398)]
# 0179.jpg
# imagesize: 1000 563
# windowsize: 900 900
# step_size: 180
# windowsize: 800 800
# step_size: 160
# windowsize: 700 700
# step_size: 140
# windowsize: 600 600
# step_size: 120
# windowsize: 500 500
# step_size: 100
# windowsize: 400 400
# step_size: 80
# windowsize: 300 300
# step_size: 60
# windowsize: 200 200
# step_size: 40
# imagesize: 1000 563
# windowsize: 229 506
# step_size: 101 45
# windowsize: 204 450
# step_size: 90 40
# windowsize: 179 394
# step_size: 78 35
# windowsize: 153 337
# step_size: 67 30
# windowsize: 127 281
# step_size: 56 25
# windowsize: 102 225
# step_size: 45 20
# Detecting traffic signs:  91%|█████████ | 79/87 [33:02<03:17, 24.63s/it]
# []
# 0442.jpg
# imagesize: 473 1000
# windowsize: 425 425
# step_size: 85
# windowsize: 378 378
# step_size: 75
# windowsize: 331 331
# step_size: 66
# windowsize: 283 283
# step_size: 56
# windowsize: 236 236
# step_size: 47
# windowsize: 189 189
# step_size: 37
# imagesize: 473 1000
# windowsize: 409 900
# step_size: 180 81
# windowsize: 363 800
# step_size: 160 72
# windowsize: 318 700
# step_size: 140 63
# windowsize: 272 600
# step_size: 120 54
# windowsize: 227 500
# step_size: 100 45
# windowsize: 181 400
# step_size: 80 36
# windowsize: 136 300
# step_size: 60 27
# windowsize: 90 200
# step_size: 40 18
# Detecting traffic signs:  92%|█████████▏| 80/87 [33:18<02:33, 21.89s/it]
# []
# 0656.jpg
# imagesize: 1000 1000
# windowsize: 900 900
# step_size: 180
# windowsize: 800 800
# step_size: 160
# windowsize: 700 700
# step_size: 140
# windowsize: 600 600
# step_size: 120
# windowsize: 500 500
# step_size: 100
# windowsize: 400 400
# step_size: 80
# windowsize: 300 300
# step_size: 60
# windowsize: 200 200
# step_size: 40
# imagesize: 1000 1000
# windowsize: 409 900
# step_size: 180 81
# windowsize: 363 800
# step_size: 160 72
# windowsize: 318 700
# step_size: 140 63
# windowsize: 272 600
# step_size: 120 54
# windowsize: 227 500
# step_size: 100 45
# windowsize: 181 400
# step_size: 80 36
# windowsize: 136 300
# step_size: 60 27
# windowsize: 90 200
# step_size: 40 18
# Detecting traffic signs:  93%|█████████▎| 81/87 [33:52<02:33, 25.53s/it]
# [(0, 360, 300, 660, 'interdiction', 0.9004967060650764), (200, 240, 290, 440, 'fvert', 0.9301621190942332), (20, 640, 110, 840, 'frouge', 0.905380421245758), (40, 640, 130, 840, 'frouge', 0.9319098480971892), (60, 640, 150, 840, 'frouge', 0.9033196634981874)]
# 0358.jpg
# imagesize: 750 1000
# windowsize: 675 675
# step_size: 135
# windowsize: 600 600
# step_size: 120
# windowsize: 525 525
# step_size: 105
# windowsize: 450 450
# step_size: 90
# windowsize: 375 375
# step_size: 75
# windowsize: 300 300
# step_size: 60
# windowsize: 225 225
# step_size: 45
# windowsize: 150 150
# step_size: 30
# imagesize: 750 1000
# windowsize: 409 900
# step_size: 180 81
# windowsize: 363 800
# step_size: 160 72
# windowsize: 318 700
# step_size: 140 63
# windowsize: 272 600
# step_size: 120 54
# windowsize: 227 500
# step_size: 100 45
# windowsize: 181 400
# step_size: 80 36
# windowsize: 136 300
# step_size: 60 27
# windowsize: 90 200
# step_size: 40 18
# Detecting traffic signs:  94%|█████████▍| 82/87 [34:23<02:16, 27.34s/it]
# [(360, 150, 510, 300, 'obligation', 0.9261881078034111), (330, 180, 480, 330, 'obligation', 0.9550242256087069), (360, 180, 510, 330, 'obligation', 0.9518785711526733), (390, 180, 540, 330, 'obligation', 0.9881926481990371), (390, 210, 540, 360, 'obligation', 0.9884698142551754), (300, 0, 572, 600, 'forange', 0.9353407149552329), (300, 120, 572, 720, 'frouge', 0.9214769725305176), (300, 0, 527, 500, 'forange', 0.9865014430422256), (50, 200, 277, 700, 'forange', 0.9658236790973769), (50, 300, 277, 800, 'frouge', 0.9305102507299218), (320, 80, 501, 480, 'forange', 0.9753264714280314), (360, 80, 541, 480, 'forange', 0.9501786999007922), (80, 240, 261, 640, 'forange', 0.9520460550147731), (390, 0, 526, 300, 'fvert', 0.9624753490473524), (360, 120, 496, 420, 'forange', 0.9450042588772358), (420, 80, 510, 280, 'fvert', 0.9314417726230444), (380, 680, 470, 880, 'forange', 0.9172221147512462), (380, 720, 470, 920, 'frouge', 0.9626615860344583)]
# 0680.jpg
# imagesize: 750 1000
# windowsize: 675 675
# step_size: 135
# windowsize: 600 600
# step_size: 120
# windowsize: 525 525
# step_size: 105
# windowsize: 450 450
# step_size: 90
# windowsize: 375 375
# step_size: 75
# windowsize: 300 300
# step_size: 60
# windowsize: 225 225
# step_size: 45
# windowsize: 150 150
# step_size: 30
# imagesize: 750 1000
# windowsize: 409 900
# step_size: 180 81
# windowsize: 363 800
# step_size: 160 72
# windowsize: 318 700
# step_size: 140 63
# windowsize: 272 600
# step_size: 120 54
# windowsize: 227 500
# step_size: 100 45
# windowsize: 181 400
# step_size: 80 36
# windowsize: 136 300
# step_size: 60 27
# windowsize: 90 200
# step_size: 40 18
# Detecting traffic signs:  95%|█████████▌| 83/87 [34:54<01:53, 28.41s/it]
# []
# 0004.jpg
# imagesize: 750 1000
# windowsize: 675 675
# step_size: 135
# windowsize: 600 600
# step_size: 120
# windowsize: 525 525
# step_size: 105
# windowsize: 450 450
# step_size: 90
# windowsize: 375 375
# step_size: 75
# windowsize: 300 300
# step_size: 60
# windowsize: 225 225
# step_size: 45
# windowsize: 150 150
# step_size: 30
# imagesize: 750 1000
# windowsize: 409 900
# step_size: 180 81
# windowsize: 363 800
# step_size: 160 72
# windowsize: 318 700
# step_size: 140 63
# windowsize: 272 600
# step_size: 120 54
# windowsize: 227 500
# step_size: 100 45
# windowsize: 181 400
# step_size: 80 36
# windowsize: 136 300
# step_size: 60 27
# windowsize: 90 200
# step_size: 40 18
# Detecting traffic signs:  97%|█████████▋| 84/87 [35:25<01:27, 29.11s/it]
# [(300, 660, 436, 960, 'fvert', 0.927028241064003), (360, 660, 496, 960, 'fvert', 0.9660656535594657), (390, 660, 526, 960, 'fvert', 0.9832285437667784), (320, 480, 410, 680, 'frouge', 0.9613296290688051), (360, 480, 450, 680, 'frouge', 0.9032521824298475), (360, 520, 450, 720, 'forange', 0.968818484165093), (380, 520, 470, 720, 'forange', 0.9773868324273959), (400, 520, 490, 720, 'forange', 0.9279897409221003), (380, 560, 470, 760, 'frouge', 0.9475118505099465), (360, 600, 450, 800, 'frouge', 0.9597353251911349), (380, 600, 470, 800, 'frouge', 0.9645047497815255), (260, 640, 350, 840, 'forange', 0.9292065789016786), (400, 640, 490, 840, 'fvert', 0.9698491777237741), (60, 720, 150, 920, 'forange', 0.9289808208696967), (400, 720, 490, 920, 'fvert', 0.9655081109467344), (420, 720, 510, 920, 'fvert', 0.9353185641575081)]
# 0827.jpg
# imagesize: 750 1000
# windowsize: 675 675
# step_size: 135
# windowsize: 600 600
# step_size: 120
# windowsize: 525 525
# step_size: 105
# windowsize: 450 450
# step_size: 90
# windowsize: 375 375
# step_size: 75
# windowsize: 300 300
# step_size: 60
# windowsize: 225 225
# step_size: 45
# windowsize: 150 150
# step_size: 30
# imagesize: 750 1000
# windowsize: 409 900
# step_size: 180 81
# windowsize: 363 800
# step_size: 160 72
# windowsize: 318 700
# step_size: 140 63
# windowsize: 272 600
# step_size: 120 54
# windowsize: 227 500
# step_size: 100 45
# windowsize: 181 400
# step_size: 80 36
# windowsize: 136 300
# step_size: 60 27
# windowsize: 90 200
# step_size: 40 18
# Detecting traffic signs:  98%|█████████▊| 85/87 [35:57<00:59, 29.87s/it]
# []
# 0131.jpg
# imagesize: 1000 1000
# windowsize: 900 900
# step_size: 180
# windowsize: 800 800
# step_size: 160
# windowsize: 700 700
# step_size: 140
# windowsize: 600 600
# step_size: 120
# windowsize: 500 500
# step_size: 100
# windowsize: 400 400
# step_size: 80
# windowsize: 300 300
# step_size: 60
# windowsize: 200 200
# step_size: 40
# imagesize: 1000 1000
# windowsize: 409 900
# step_size: 180 81
# windowsize: 363 800
# step_size: 160 72
# windowsize: 318 700
# step_size: 140 63
# windowsize: 272 600
# step_size: 120 54
# windowsize: 227 500
# step_size: 100 45
# windowsize: 181 400
# step_size: 80 36
# windowsize: 136 300
# step_size: 60 27
# windowsize: 90 200
# step_size: 40 18
# Detecting traffic signs:  99%|█████████▉| 86/87 [36:29<00:30, 30.64s/it]
# []
# 0717.jpg
# imagesize: 750 1000
# windowsize: 675 675
# step_size: 135
# windowsize: 600 600
# step_size: 120
# windowsize: 525 525
# step_size: 105
# windowsize: 450 450
# step_size: 90
# windowsize: 375 375
# step_size: 75
# windowsize: 300 300
# step_size: 60
# windowsize: 225 225
# step_size: 45
# windowsize: 150 150
# step_size: 30
# imagesize: 750 1000
# windowsize: 409 900
# step_size: 180 81
# windowsize: 363 800
# step_size: 160 72
# windowsize: 318 700
# step_size: 140 63
# windowsize: 272 600
# step_size: 120 54
# windowsize: 227 500
# step_size: 100 45
# windowsize: 181 400
# step_size: 80 36
# windowsize: 136 300
# step_size: 60 27
# windowsize: 90 200
# step_size: 40 18
# Detecting traffic signs: 100%|██████████| 87/87 [36:59<00:00, 25.51s/it]
# []

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Load the data
validations = pd.read_csv('validations.csv', header=None)
detections = pd.read_csv('detections.csv', header=None)

# Filter out the 'ff' labels
validations = validations[validations.iloc[:, 5] != 'ff']
detections = detections[detections.iloc[:, 6] != 'ff']

# Function to check if a value can be converted to float
def is_float(value):
    try:
        float(value)
        return True
    except ValueError:
        print(f"{value} rejected")
        return False

# Ensure the data types are correct and filter out non-numeric rows
validations = validations[validations.iloc[:, 1:5].map(is_float).all(axis=1)]
detections = detections[detections.iloc[:, 1:5].map(is_float).all(axis=1)]

validations.iloc[:, 1:5] = validations.iloc[:, 1:5].astype(float)
detections.iloc[:, 1:5] = detections.iloc[:, 1:5].astype(float)
detections.iloc[:, 5] = detections.iloc[:, 5].astype(float)
# Out:
# Coin h-g x rejected
# Coin h-g y rejected
# Coin b-d x rejected
# Coin b-d y rejected

# %%
#add the negativ samples
from gen_neg import get_negative_prediction
negative_samples_dir = "dataset/train/images/cropped_images"
image_folder_path = "dataset/val/images"
get_negative_prediction(detections, validations,image_folder_path, negative_samples_dir)

# %%
# Initialize lists to store y (ground truth) and y_pred (predictions)
y = []
y_pred = []
matching_validation_row = []
fp_data = []

# Define IoU function
def iou(box1, box2):
    # Unpack the coordinates
    x1_min, y1_min, x1_max, y1_max = box1
    x2_min, y2_min, x2_max, y2_max = box2

    # Calculate the intersection coordinates
    inter_x_min = max(x1_min, x2_min)
    inter_y_min = max(y1_min, y2_min)
    inter_x_max = min(x1_max, x2_max)
    inter_y_max = min(y1_max, y2_max)

    # Calculate the intersection area
    inter_area = max(0, inter_x_max - inter_x_min) * max(0, inter_y_max - inter_y_min)

    # Calculate the areas of each box
    box1_area = (x1_max - x1_min) * (y1_max - y1_min)
    box2_area = (x2_max - x2_min) * (y2_max - y2_min)

    # Calculate the union area
    union_area = box1_area + box2_area - inter_area

    # Calculate the IoU
    iou = inter_area / union_area

    return iou

# Match detections with ground truth
for _, detection_row in detections.iterrows():
    image_id_d, x_min_d, y_min_d, x_max_d, y_max_d, score_d, label_d = detection_row
    max_iou = 0.5
    matching_validation = 'none'

    for idx, validation_row in validations.iterrows():
        image_id_v, x_min_v, y_min_v, x_max_v, y_max_v, label_v = validation_row
        
        if image_id_v == image_id_d and label_v == label_d:
            iou_value = iou((x_min_v, y_min_v, x_max_v, y_max_v), (x_min_d, y_min_d, x_max_d, y_max_d))
            
            if iou_value > max_iou:
                max_iou = iou_value
                matching_validation = label_v
                
                matching_validation_row.append(idx)
    
    # Add ground truth and prediction based on maximum IoU
    y_pred.append(label_d)
    y.append(matching_validation)
    
    if matching_validation == 'none':
        fp_data.append(list(detection_row))

for idx, validation_row in validations.iterrows():
    image_id_v, x_min_v, y_min_v, x_max_v, y_max_v, label_v = validation_row
    if idx not in matching_validation_row:
        y.append(label_v)
        y_pred.append('none')

# Plot confusion matrix
cm = confusion_matrix(y, y_pred, normalize=True)
# Get unique labels
unique_labels = sorted(list(set(y)))

plt.figure(figsize=(10, 7))
sns.heatmap(
    cm,
    annot=True,
    fmt=".2%",
    xticklabels=unique_labels,
    yticklabels=unique_labels,
    cmap="Blues",
)
plt.xlabel("Predicted")
plt.ylabel("Truth")
plt.show()

# Calculate precision and recall
precision = {}
recall = {}

for i in range(len(unique_labels)):
    cls = unique_labels[i]
    tp = cm[i, i]
    fp = np.sum(cm[:, i]) - tp
    fn = np.sum(cm[i, :]) - tp
    
    precision[cls] = tp / (tp + fp) if tp + fp > 0 else 0
    recall[cls] = tp / (tp + fn) if tp + fn > 0 else 0

print("Precision:\n", precision)
print("\nRecall:\n", recall)

tp_total = np.sum(np.diag(cm))
fp_total = np.sum(cm) - tp_total
fn_total = np.sum(cm) - tp_total

overall_precision = tp_total / (tp_total + fp_total) if tp_total + fp_total > 0 else 0
overall_recall = tp_total / (tp_total + fn_total) if tp_total + fn_total > 0 else 0

print("\nOverall precision:\n", overall_precision)
print("\nOverall recall:\n", overall_recall)
# Out:
# Coin h-g x rejected
# Coin h-g y rejected
# Coin b-d x rejected
# Coin b-d y rejected
# Precision:
#  {'ceder': 0.7, 'danger': 0.38461538461538464, 'forange': 0.0, 'frouge': 0.03571428571428571, 'fvert': 0.0, 'interdiction': 0.45454545454545453, 'none': 0.0, 'obligation': 0.23076923076923078, 'stop': 1.0}
#
# Recall:
#  {'ceder': 0.4375, 'danger': 0.2631578947368421, 'forange': 0.0, 'frouge': 0.07692307692307693, 'fvert': 0.0, 'interdiction': 0.11363636363636363, 'none': 0.0, 'obligation': 0.1875, 'stop': 0.5}
#
# Overall precision:
#  0.11244979919678715
#
# Overall recall:
#  0.11244979919678715

# %%
print(fp_data)
# Out:
# [['Num img', 'Coin h-g x', 'Coin h-g y', 'Coin b-d x', 'Coin b-d y', 'Score', 'Classe'], ['0297.jpg', '520', '400', '610', '600', '0.9194947608648661', 'fvert'], ['0297.jpg', '300', '320', '390', '520', '0.9172796257386443', 'fvert'], ['0810.jpg', '280', '680', '370', '880', '0.9772999953442412', 'fvert'], ['0810.jpg', '340', '520', '430', '720', '0.9212079487709047', 'fvert'], ['0419.jpg', '420', '0', '510', '200', '0.9836610330519826', 'fvert'], ['0419.jpg', '100', '280', '190', '480', '0.9763644024826471', 'fvert'], ['0419.jpg', '200', '40', '290', '240', '0.9709444285473677', 'forange'], ['0419.jpg', '480', '240', '570', '440', '0.9609610236707011', 'fvert'], ['0419.jpg', '360', '360', '496', '660', '0.9580471753704278', 'frouge'], ['0419.jpg', '200', '320', '290', '520', '0.9323649768339679', 'frouge'], ['0419.jpg', '0', '0', '90', '200', '0.9231160044272056', 'forange'], ['0733.jpg', '600', '240', '736', '540', '0.9704493357418088', 'fvert'], ['0733.jpg', '520', '440', '610', '640', '0.9603805718828561', 'forange'], ['0733.jpg', '240', '0', '330', '200', '0.9561117053703173', 'fvert'], ['0733.jpg', '120', '0', '210', '200', '0.9080549896538475', 'fvert']]
